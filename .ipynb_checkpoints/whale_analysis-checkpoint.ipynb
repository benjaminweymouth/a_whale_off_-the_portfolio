# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial import statements 
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
whale_data = Path("./Resources/whale_returns.csv")
whale_data
# Out:
# WindowsPath('Resources/whale_returns.csv')

# %%
# Reading whale returns
whale_df = pd.read_csv(whale_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
whale_df.sort_index(axis=0, level=None, ascending=True, inplace=True, kind='quicksort')
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
#check for nulls 
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_data = Path("./Resources/algo_returns.csv")
algo_data
# Out:
# WindowsPath('Resources/algo_returns.csv')

# %%
# Reading whale returns
algo_data_df = pd.read_csv(algo_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_data_df.sort_index(axis=0, level=None, ascending=True, inplace=True, kind='quicksort')
algo_data_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_data_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_data_df.dropna(inplace=True)
algo_data_df.head()
#check for nulls 
algo_data_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
algo_data_df.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_tsx_data = Path("./Resources/sp_tsx_history.csv")
sp_tsx_data
sp_tsx_df = pd.read_csv(sp_tsx_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp_tsx_df.sort_index(axis=0, level=None, ascending=True, inplace=True, kind='quicksort')
sp_tsx_df.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
sp_tsx_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp_tsx_df["Close"] = sp_tsx_df["Close"].str.replace("$", "")
sp_tsx_df["Close"] = sp_tsx_df["Close"].str.replace(",", "")
sp_tsx_df.head()
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99

# %%
#convert to float 
sp_tsx_df["Close"] = sp_tsx_df["Close"].astype('float')

# Re-Check Data Types
sp_tsx_df["Close"].dtypes
sp_tsx_df.head()
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99

# %%
# Calculate Daily Returns
tsx_daily_returns = sp_tsx_df.pct_change()
tsx_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305

# %%
# Count nulls
tsx_daily_returns.isnull().sum()

# Drop nulls

tsx_daily_returns.dropna(inplace=True)
tsx_daily_returns.head()
#check for nulls 
tsx_daily_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
tsx_daily_returns.columns = ["S&P TSX"]
tsx_daily_returns.head()
# Out:
#              S&P TSX
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
# Use the concat function to combine the DataFrames by column and perform an inner join. 
combined_df = pd.concat([whale_df, algo_data_df,tsx_daily_returns], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
combined_df.sort_index(inplace=True)

# Display a few rows
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P TSX
# Date
# 2015-03-03 -0.000949 -0.008530
# 2015-03-04  0.002416 -0.003371
# 2015-03-05  0.004323  0.001344
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot(figsize=(15,10),title='Daily Returns, Combined')
# Out:
# <AxesSubplot:title={'center':'Daily Returns, Combined'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
 # Use the `cumprod` function to calculate cumulative returns
cumulative_returns = (1 + combined_df).cumprod()
# Display sample values
cumulative_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# 2015-03-06                     0.990844                0.991172  0.983641
# 2015-03-09                     0.996633                0.989534  0.978283
#
#               Algo 2   S&P TSX
# Date
# 2015-03-03  0.999051  0.991470
# 2015-03-04  1.001464  0.988128
# 2015-03-05  1.005794  0.989456
# ...

# %%
# Plot cumulative returns
cumulative_returns.plot(figsize=(15,10),title='Cumulative Returns, Combined')
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns, Combined'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_df.boxplot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
st_dev_series = combined_df.std()

#a series holding all the standard deviations
st_dev_series
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# S&P TSX                        0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
std_TSX = combined_df["S&P TSX"].std()

# Determine which portfolios are riskier than the S&P TSX 60
for index, value in st_dev_series.items():
        if index != "S&P TSX":
            if value > std_TSX:
                print(f"{index} has more risk than the S&P TSX 60 due to an std of {round(value, 5)}")
# Out:
# SOROS FUND MANAGEMENT LLC has more risk than the S&P TSX 60 due to an std of 0.00783
# TIGER GLOBAL MANAGEMENT LLC has more risk than the S&P TSX 60 due to an std of 0.01088
# BERKSHIRE HATHAWAY INC has more risk than the S&P TSX 60 due to an std of 0.01283
# Algo 1 has more risk than the S&P TSX 60 due to an std of 0.00759
# Algo 2 has more risk than the S&P TSX 60 due to an std of 0.00833

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = st_dev_series * np.sqrt(252)
annualized_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
# Plot the rolling standard deviation
combined_df.rolling(window=21).std().plot(figsize=(15,10),title='Rolling standard deviation, Combined')
# Out:
# <AxesSubplot:title={'center':'Rolling standard deviation, Combined'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = combined_df.corr()

# Display de correlation matrix
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.697076
# PAULSON & CO.INC.                             0.697076            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.560964            0.433034
# BERKSHIRE HATHAWAY INC                        0.750181            0.540033
# Algo 1                                        0.313795            0.266363
# Algo 2                                        0.826667            0.674015
# S&P TSX                                       0.673930            0.486511
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.560964
# PAULSON & CO.INC.                               0.433034
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.423524
# Algo 1                                          0.161236
# ...

# %%
# Use the `heatmap` function from the Seaborn library to visualize the correlation table
sns.heatmap(correlation, vmin=-1, vmax=1,)
# Out:
# <AxesSubplot:>

# %%
# Alternatively, sum total correlation for each stock
correlation_series = correlation.sum(axis=0).sort_values()
correlation_series
# Out:
# Algo 1                         2.626504
# TIGER GLOBAL MANAGEMENT LLC    3.526030
# PAULSON & CO.INC.              4.097032
# S&P TSX                        4.205921
# BERKSHIRE HATHAWAY INC         4.244975
# Algo 2                         4.714805
# SOROS FUND MANAGEMENT LLC      4.822611
# dtype: float64

# %%
#Find the 2 highest values indicating the highest correlation 

highest_value = correlation_series.max()
max_index = correlation_series.idxmax()
cleaned_series = correlation_series.drop(index=max_index)
second_highest_index = cleaned_series.idxmax()
second_highest_value = cleaned_series.max()
print(f"The two highest correlated stocks are {max_index} with {round(highest_value, 4)} and {second_highest_index} with {round(second_highest_value, 4)}")
# Out:
# The two highest correlated stocks are SOROS FUND MANAGEMENT LLC with 4.8226 and Algo 2 with 4.7148

# %%
# Drop highly correlated stocks and keep only the non-correlated stocks
noncorrelated_daily_returns = combined_df.drop(columns=["SOROS FUND MANAGEMENT LLC", "Algo 2"])

# Display sample data
noncorrelated_daily_returns.head()
# Out:
#             PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# Date
# 2015-03-03           -0.004981                    -0.000496
# 2015-03-04            0.003241                    -0.002534
# 2015-03-05            0.004076                     0.002355
# 2015-03-06           -0.003574                    -0.008481
# 2015-03-09            0.004225                     0.005843
#
#             BERKSHIRE HATHAWAY INC    Algo 1   S&P TSX
# Date
# 2015-03-03               -0.006569 -0.001942 -0.008530
# 2015-03-04                0.004213 -0.008589 -0.003371
# 2015-03-05                0.006726 -0.000955  0.001344
# 2015-03-06               -0.013098 -0.004957 -0.009972
# 2015-03-09               -0.001652 -0.005447 -0.006555

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
algo_covariance = combined_df['Algo 1'].cov(combined_df['S&P TSX'])

# Calculate 60-day rolling covariance of Algo 1 vs. TSX rolling variance
algo_rolling_covariance = combined_df['Algo 1'].rolling(window=60).cov(combined_df['S&P TSX'])

# Calculate variance of S&P TSX
tsx_variance = combined_df['S&P TSX'].var()
algo_variance = combined_df['Algo 1'].var()
tsx_rolling_variance = combined_df['S&P TSX'].rolling(window=60).var()

# Computing beta
algo_beta = algo_covariance / tsx_variance
algo_rolling_beta = algo_rolling_covariance / tsx_rolling_variance

# Plot beta trend
 
algo_rolling_beta.plot(figsize=(15,10), title='Beta for Algo 1 Returns vs. S&P TSX Returns')
# Out:
# <AxesSubplot:title={'center':'Beta for Algo 1 Returns vs. S&P TSX Returns'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
ewm_result = combined_df.ewm(com=None, span=None, halflife=21).mean()
ewm_result.plot(figsize=(15,10), title='Exponentially Weighted Average')
# Out:
# <AxesSubplot:title={'center':'Exponentially Weighted Average'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios

# Use the `mean` and `std` functions to calculate the annualized sharpe ratio
sharpe_ratios = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))

# Display sharpe ratios
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# S&P TSX                        0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot.bar(x=None, y=None, figsize=(15,10), title='Sharpe Ratios')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ### Analysis: algorithmic strategies ###
#
# In order to determine whether the algorithmic strategies perform better, we will analyse this bar chart showing the Sharpe Ratio to compare different portfolios. Risk tolerance is our main metric for assigning a value proposition to performance. Thus we can draw four conclusions from this bar plot.
#
# ### Conclusions ###
# -----------------------------
# * Conclusion 1: Since this sharpe ratio bar plot is an an estimation of a portfolios value, it is clear that Algo 1 is a clear winner in terms of low risk and low volatility. Therefore, it could said to clearly outperform the other portfolios when utilizing low-risk as a metric to compare various portfolios.
# * Conclusion 2: It is noticeable that Algo 2 is clearly underperforming when compared to Algo 1. Furthermore, it has a higher level of risk than Berkshire Hathaway Inc.
# * Conclusion 3: Algo 1 and Algo 2 both have a better risk-to-return than the S&P TSX 60. However, Algo 1 performs much better than the TSX while Algo 2 is only a marginally better selection.
# * Conclusion 4: The Whale Portfolios are noticeably worse performers when utilizing the Sharpe Ratio as a key performance indicator (KPI). While Berkshire Hathaway is the clear leader of the Whale Portfolios, most are not close to the low risk / low volatility offered by Algo 1.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P TSX 60 index.
#
# * `SHOP` - [Shopify Inc](https://en.wikipedia.org/wiki/Shopify)
#
# * `OTEX` - [Open Text Corporation](https://en.wikipedia.org/wiki/OpenText)
#
# * `L` - [Loblaw Companies Limited](https://en.wikipedia.org/wiki/Loblaw_Companies)

# %%
#Go to Google Finance 
#pick 3 stocks: Nvidia, Intel and Google.

# %%
#getting the Nvidia stock from google finance
#code for Nvidia data: 
#=GOOGLEFINANCE("NASDAQ:NVDA", "price", DATE(2018,1,2), DATE(2019,12,30), "DAILY")

# %% [markdown]
# ###Screencapture for Nvidia ticker 'NVDA' on Google Sheets:
# [![GoogleScreencap](/Images/nvidia_screenshot.png)](https://github.com/benjaminweymouth/a_whale_off_-the_portfolio/blob/main/Resources/nvidia_historical.csv)

# %%
#getting the Intel stock from google finance
#code for Intel data: 
#=GOOGLEFINANCE("NASDAQ:INTC", "price", DATE(2018,1,2), DATE(2019,12,30), "DAILY")

# %% [markdown]
# ###Screencapture for Intel ticker 'INTC' on Google Sheets:
# [![IntelScreencap](/Images/intel_screenshot.png)](https://github.com/benjaminweymouth/a_whale_off_-the_portfolio/blob/main/Resources/intel_historical.csv)

# %%
#getting the google stock from google finance
#code for Google data: 
#=GOOGLEFINANCE("NASDAQ:GOOG", "price", DATE(2018,1,2), DATE(2019,12,30), "DAILY")

# %% [markdown]
# ###Screencapture for Google ticker 'GOOG' on Google Sheets:
#
# [![GoogleScreencap](/Images/google_screenshot.png)](https://github.com/benjaminweymouth/a_whale_off_-the_portfolio/blob/main/Resources/google_historical.csv)

# %%
# Reading data from 1st stock

nvidia_data = Path("./Resources/nvidia_historical.csv")
 
nvidia_df = pd.read_csv(nvidia_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
nvidia_df.sort_index(axis=0, level=None, ascending=True, inplace=True, kind='quicksort')
# Rename `Close` Column to be specific to this portfolio.
nvidia_df.columns = ["NVDA"]
nvidia_df.head()
# Out:
#                       NVDA
# Date
# 2018-01-02 16:00:00  49.84
# 2018-01-03 16:00:00  53.12
# 2018-01-04 16:00:00  53.40
# 2018-01-05 16:00:00  53.85
# 2018-01-08 16:00:00  55.50

# %%
# Count nulls
nvidia_df.isnull().sum()
# Out:
# NVDA    0
# dtype: int64

# %%
# Reading data from 2nd stock
 

intel_data = Path("./Resources/intel_historical.csv")
 
intel_df = pd.read_csv(intel_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
intel_df.sort_index(axis=0, level=None, ascending=True, inplace=True, kind='quicksort')
# Rename `Close` Column to be specific to this portfolio.
intel_df.columns = ["INTC"]
intel_df.head()
# Out:
#                       INTC
# Date
# 2018-01-02 16:00:00  46.85
# 2018-01-03 16:00:00  45.26
# 2018-01-04 16:00:00  44.43
# 2018-01-05 16:00:00  44.74
# 2018-01-08 16:00:00  44.74

# %%
# Count nulls
intel_df.isnull().sum()
# Out:
# INTC    0
# dtype: int64

# %%
# Reading data from 3rd stock
google_data = Path("./Resources/google_historical.csv")
 
google_df = pd.read_csv(google_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
google_df.sort_index(axis=0, level=None, ascending=True, inplace=True, kind='quicksort')
# Rename `Close` Column to be specific to this portfolio.
google_df.columns = ["GOOG"]
google_df.head()
# Out:
#                         GOOG
# Date
# 2018-01-02 16:00:00  1065.00
# 2018-01-03 16:00:00  1082.48
# 2018-01-04 16:00:00  1086.40
# 2018-01-05 16:00:00  1102.23
# 2018-01-08 16:00:00  1106.94

# %%
# Count nulls
google_df.isnull().sum()
# Out:
# GOOG    0
# dtype: int64

# %%
# Combine all stocks in a single DataFrame
# Reorganize portfolio data by having a column per symbol
custom_combined_df = pd.concat([nvidia_df, intel_df,google_df], axis="columns", join="inner")

# Display a few rows
custom_combined_df.head()
# Out:
#                       NVDA   INTC     GOOG
# Date
# 2018-01-02 16:00:00  49.84  46.85  1065.00
# 2018-01-03 16:00:00  53.12  45.26  1082.48
# 2018-01-04 16:00:00  53.40  44.43  1086.40
# 2018-01-05 16:00:00  53.85  44.74  1102.23
# 2018-01-08 16:00:00  55.50  44.74  1106.94

# %%
# Reset Date index
custom_combined_df.index = custom_combined_df.index.date

# %%
# Sort datetime index in ascending order (past to present)
custom_combined_df.sort_index(inplace=True)
custom_combined_df.head()
# Out:
#              NVDA   INTC     GOOG
# 2018-01-02  49.84  46.85  1065.00
# 2018-01-03  53.12  45.26  1082.48
# 2018-01-04  53.40  44.43  1086.40
# 2018-01-05  53.85  44.74  1102.23
# 2018-01-08  55.50  44.74  1106.94

# %%
# Calculate daily returns
daily_returns = custom_combined_df.pct_change()
daily_returns.head()
# Out:
#                 NVDA      INTC      GOOG
# 2018-01-02       NaN       NaN       NaN
# 2018-01-03  0.065811 -0.033938  0.016413
# 2018-01-04  0.005271 -0.018338  0.003621
# 2018-01-05  0.008427  0.006977  0.014571
# 2018-01-08  0.030641  0.000000  0.004273

# %%
# Drop NAs
daily_returns.dropna(inplace=True)

# Display sample data
daily_returns.head()
# Out:
#                 NVDA      INTC      GOOG
# 2018-01-03  0.065811 -0.033938  0.016413
# 2018-01-04  0.005271 -0.018338  0.003621
# 2018-01-05  0.008427  0.006977  0.014571
# 2018-01-08  0.030641  0.000000  0.004273
# 2018-01-09 -0.000180 -0.025034 -0.000614

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_returns = daily_returns.dot(weights)
portfolio_returns.head()
# Out:
# 2018-01-03    0.016095
# 2018-01-04   -0.003149
# 2018-01-05    0.009992
# 2018-01-08    0.011638
# 2018-01-09   -0.008609
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
custom_combined_df = pd.concat([combined_df, portfolio_returns], axis="columns", join="inner")

# Sort datetime index in ascending order (past to present)
custom_combined_df.sort_index(inplace=True)

# Display a few rows
custom_combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-01-03                     0.001979                0.005676 -0.000890
# 2018-01-04                     0.010743                0.004065 -0.000914
# 2018-01-05                     0.000737                0.022023 -0.003839
# 2018-01-08                     0.005085                0.003435  0.001653
# 2018-01-09                     0.001789                0.000708 -0.001004
#
#               Algo 2   S&P TSX         0
# 2018-01-03  0.008175  0.003774  0.016095
# 2018-01-04  0.004294  0.002528 -0.003149
# 2018-01-05  0.006405 -0.003869  0.009992
# ...

# %%
custom_combined_df.rename( columns={0:'Custom Portfolio'}, inplace=True )
custom_combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-01-03                     0.001979                0.005676 -0.000890
# 2018-01-04                     0.010743                0.004065 -0.000914
# 2018-01-05                     0.000737                0.022023 -0.003839
# 2018-01-08                     0.005085                0.003435  0.001653
# 2018-01-09                     0.001789                0.000708 -0.001004
#
#               Algo 2   S&P TSX  Custom Portfolio
# 2018-01-03  0.008175  0.003774          0.016095
# 2018-01-04  0.004294  0.002528         -0.003149
# ...

# %%
#check headers / column names
custom_combined_df.keys()
# Out:
# Index(['SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC', 'Algo 1',
#        'Algo 2', 'S&P TSX', 'Custom Portfolio'],
#       dtype='object')

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
#check for nulls 
custom_combined_df.isnull().sum()
# Drop nulls
custom_combined_df.dropna(inplace=True)
#check for nulls again
custom_combined_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P TSX                        0
# Custom Portfolio               0
# dtype: int64

# %%
custom_combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-01-03                     0.001979                0.005676 -0.000890
# 2018-01-04                     0.010743                0.004065 -0.000914
# 2018-01-05                     0.000737                0.022023 -0.003839
# 2018-01-08                     0.005085                0.003435  0.001653
# 2018-01-09                     0.001789                0.000708 -0.001004
#
#               Algo 2   S&P TSX  Custom Portfolio
# 2018-01-03  0.008175  0.003774          0.016095
# 2018-01-04  0.004294  0.002528         -0.003149
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
 # Calculate the daily standard deviations of all portfolios
custom_st_dev_series = custom_combined_df.std()

#a series holding all the standard deviations
custom_st_dev_series

# Calculate the annualized standard deviation (252 trading days)
custom_annualized_std = custom_st_dev_series * np.sqrt(252)
custom_annualized_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.145675
# PAULSON & CO.INC.              0.114343
# TIGER GLOBAL MANAGEMENT LLC    0.219833
# BERKSHIRE HATHAWAY INC         0.227445
# Algo 1                         0.120028
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
# Plot the rolling standard deviation
custom_combined_df.rolling(window=21).std().plot(figsize=(15,10),title='Rolling standard deviation, Combined')
# Out:
# <AxesSubplot:title={'center':'Rolling standard deviation, Combined'}>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
custom_correlation = custom_combined_df.corr()

# Display de correlation matrix
custom_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.764174
# PAULSON & CO.INC.                             0.764174            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.526710            0.536534
# BERKSHIRE HATHAWAY INC                        0.782414            0.647407
# Algo 1                                        0.305525            0.320568
# Algo 2                                        0.834431            0.797494
# S&P TSX                                       0.686681            0.623728
# Custom Portfolio                              0.685086            0.603325
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.526710
# PAULSON & CO.INC.                               0.536534
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.384316
# ...

# %%
# Use the `heatmap` function from the Seaborn library to visualize the correlation table
sns.heatmap(custom_correlation, vmin=-1, vmax=1,)
# Out:
# <AxesSubplot:>

# %%
# Alternatively, sum total correlation for each stock
custom_correlation_series = custom_correlation.sum(axis=0).sort_values()
custom_correlation_series
# Out:
# Algo 1                         2.878575
# TIGER GLOBAL MANAGEMENT LLC    3.881223
# Custom Portfolio               4.956829
# S&P TSX                        4.997143
# PAULSON & CO.INC.              5.293229
# BERKSHIRE HATHAWAY INC         5.329292
# SOROS FUND MANAGEMENT LLC      5.585022
# Algo 2                         5.699514
# dtype: float64

# %%
#Find the 2 highest values indicating the highest correlation 

cus_highest_value = custom_correlation_series.max()
cus_max_index = custom_correlation_series.idxmax()
cus_cleaned_series = custom_correlation_series.drop(index=cus_max_index)
cus_second_highest_index = cus_cleaned_series.idxmax()
cus_second_highest_value = cus_cleaned_series.max()
print(f"The two highest correlated stocks are {cus_max_index} with {round(cus_highest_value, 4)} and {cus_second_highest_index} with {round(cus_second_highest_value, 4)}")
# Out:
# The two highest correlated stocks are Algo 2 with 5.6995 and SOROS FUND MANAGEMENT LLC with 5.585

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
cust_algo_covariance = custom_combined_df['Custom Portfolio'].cov(custom_combined_df['S&P TSX'])

# Calculate 60-day rolling covariance of Algo 1 vs. TSX rolling variance
cust_algo_rolling_covariance = custom_combined_df['Custom Portfolio'].rolling(window=60).cov(custom_combined_df['S&P TSX'])

# Calculate variance of S&P TSX
cust_tsx_rolling_variance = custom_combined_df['S&P TSX'].rolling(window=60).var()

# Computing beta
cust_algo_rolling_beta = cust_algo_rolling_covariance / cust_tsx_rolling_variance

# Plot beta trend
cust_algo_rolling_beta.plot(figsize=(15,10), title='Beta for Custom Portfolio vs. S&P TSX')
# Out:
# <AxesSubplot:title={'center':'Beta for Custom Portfolio vs. S&P TSX'}>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
custom_combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-01-03                   0.004658            0.000027
# 2018-01-04                  -0.000914            0.004196
# 2018-01-05                   0.004072            0.000823
# 2018-01-08                   0.004473           -0.003739
# 2018-01-09                  -0.001028            0.000872
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-01-03                     0.001979                0.005676 -0.000890
# 2018-01-04                     0.010743                0.004065 -0.000914
# ...

# %%
# Annualized Sharpe Ratios

# Use the `mean` and `std` functions to calculate the annualized sharpe ratio
custom_sharpe_ratios = (custom_combined_df.mean() * 252) / (custom_combined_df.std() * np.sqrt(252))

# Display sharpe ratios
custom_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC     -0.088196
# PAULSON & CO.INC.             -0.396282
# TIGER GLOBAL MANAGEMENT LLC   -1.391612
# BERKSHIRE HATHAWAY INC         0.195907
# Algo 1                         1.901461
# Algo 2                         0.021394
# S&P TSX                        0.034651
# Custom Portfolio               0.138777
# dtype: float64

# %%
# Visualize the Custom sharpe ratios as a bar plot
custom_sharpe_ratios.plot.bar(x=None, y=None, figsize=(15,10), title='Sharpe Ratios')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %% [markdown]
# ### Analysis: Custom Porfolio ###
#
# This analysis is to compare the results of my custom portfolio to the Whale Portfolios and the S&P TSX 60. As before, we are focusing on the Sharpe Ratio to compare different portfolios. The Custom Portfolio is based on three stocks: Google, Nvidia and Intel. These are three high-performing stocks, however they may have risk associated with them based on our volatility analysis. Here are three conclusions regarding this analysis.
#
# ### New Conclusions ###
# -----------------------------
# * Conclusion 1: The custom portfolio of Nvidia, Google and Intel are clearly not performing as well in terms of the Sharpe Ratio. While Algo 1 is the clear winner in terms of risk-return, the custom portfolio is fairly close behind  Berkshire Hathaway Inc. Thus it is not the worst performer in this bar-plot.
# * Conclusion 2: When we compare the custom portfolio to the Whale Portfolios, and exclude Berkshire Hathaway Inc, it performs marginally well.
# * Conclusion 3: Currently we are utilizing an equal 1/3 ratio for the stocks. The risk-return outcome may be slightly adjusted by modifying this ratio. Another possible weighting could be 25%, 25%, 50%. Specifically the 50% could go to the lowest risk stock of the custom portfolio.
